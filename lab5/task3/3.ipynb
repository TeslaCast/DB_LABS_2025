# %% [markdown]
# Проанализируйте учебную базу данных и проиндексируйте одно из полей любой таблицы. Объясните свой выбор.

# %% [markdown]
# CREATE INDEX idx_field_comprehensions_student_id
# ON public.field_comprehensions (student_id);

# %% [markdown]
# ![изображение.png](attachment:изображение.png)

# %% [markdown]
# Поле student_id в таблице field_comprehensions часто используется для фильтрации. Индекс на student_id ускорит операции WHERE student_id = X и JOIN с таблицей students по этому полю.

# %% [markdown]
# Индекс на student_id  ускорит типичные запросы, связанные с оценками студентов
